# %%
pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (1.5)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from yellowbrick) (1.7.3)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from yellowbrick) (1.0.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from yellowbrick) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from yellowbrick) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lmeji\anaconda3\envs\pythondata\envs\mlenv\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.0)

# %%
#Load Packages
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Ridge, Lasso
import numpy as np
from sklearn import metrics
import seaborn as sns
from yellowbrick.regressor import PredictionError, ResidualsPlot

# %%
#Import csv file and create data frame
#df = pd.read_csv(Path('..Resources/SP500&Gas.csv'))
#pd.read_csv('SP500 & Gas',encoding = "utf-8")
#kwds.update(kwds_defaults)
#return _read(r"C:\Users\lmeji\Desktop\Project_branch\Investing_Analysis\Resources\SP500&Gas.csv", kwds)
data = Path(r"C:\Users\lmeji\Desktop\Project_branch\Investing_Analysis\Resources\ExportingMainData_Gas_Stocks.csv")
data_df = pd.read_csv(data)
data_df.head()
# Out:
#    weekly_date  weekly_ending_stocks_of_gasoline  \
# 0        36528                            194173
# 1        36535                            198240
# 2        36549                            201447
# 3        36556                            200937
# 4        36563                            199593
#
#    weekly_regular_retail_gasoline_prices  gspc_open  gspc_high  gspc_low  \
# 0                                  1.272    1469.25    1478.00   1438.36
# 1                                  1.264    1441.47    1464.36   1441.47
# 2                                  1.315    1441.36    1454.09   1395.42
# 3                                  1.316    1360.16    1394.48   1350.14
# 4                                  1.325    1424.37    1427.15   1413.33
#
#    gspc_close  gspc_volume  gspc_adjusted    xom    cvx
# 0     1455.22    931800000        1455.22  39.75  42.94
# 1     1457.60   1064800000        1457.60  42.09  45.03
# 2     1401.53   1115800000        1401.53  42.72  44.75
# 3     1394.46    993800000        1394.46  39.31  41.03
# 4     1424.24    918100000        1424.24  39.75  39.56

# %%
#parser = TextFileReader("C:\\Users\\lmeji\\Desktop\\Project_branch\\Investing_Analysis\\Resources\\SP500 & Gas.csv"

# %%
#Double check the data shape
#this is help to understand if we are dealing with a long (more rows than columns) or wide set (more columns than rows)

print(data_df.shape)
# Out:
# (1061, 11)

# %%
#import math
#from math import trunc

#num = ('GSPC_Open','GSPC_High','GSPC_Low','GSPC_Close','GSPC_Volume','GSPC_Adjusted','Gas_Price')
#df['GSPC_Open'] = df['GSPC_Open'].astype(int)

# %%
#Check out the data types: this could reveal additonal conversions that might need to happen 

data_df.dtypes
# Out:
# weekly_date                                int64
# weekly_ending_stocks_of_gasoline           int64
# weekly_regular_retail_gasoline_prices    float64
# gspc_open                                float64
# gspc_high                                float64
# gspc_low                                 float64
# gspc_close                               float64
# gspc_volume                                int64
# gspc_adjusted                            float64
# xom                                      float64
# cvx                                      float64
# dtype: object

# %%
#Remove rows that have at least 1 null value.

new_data = data_df.dropna()

#Check the dataset shape and head to make sure the nulls were removed

print(new_data.shape)

new_data.head()
# Out:
# (1061, 11)
#    weekly_date  weekly_ending_stocks_of_gasoline  \
# 0        36528                            194173
# 1        36535                            198240
# 2        36549                            201447
# 3        36556                            200937
# 4        36563                            199593
#
#    weekly_regular_retail_gasoline_prices  gspc_open  gspc_high  gspc_low  \
# 0                                  1.272    1469.25    1478.00   1438.36
# 1                                  1.264    1441.47    1464.36   1441.47
# 2                                  1.315    1441.36    1454.09   1395.42
# 3                                  1.316    1360.16    1394.48   1350.14
# 4                                  1.325    1424.37    1427.15   1413.33
#
#    gspc_close  gspc_volume  gspc_adjusted    xom    cvx
# 0     1455.22    931800000        1455.22  39.75  42.94
# 1     1457.60   1064800000        1457.60  42.09  45.03
# 2     1401.53   1115800000        1401.53  42.72  44.75
# 3     1394.46    993800000        1394.46  39.31  41.03
# 4     1424.24    918100000        1424.24  39.75  39.56

# %%
# Checking for null values
print(data_df.info())

# Checking for outliers
print(data_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   weekly_date                            1061 non-null   int64
#  1   weekly_ending_stocks_of_gasoline       1061 non-null   int64
#  2   weekly_regular_retail_gasoline_prices  1061 non-null   float64
#  3   gspc_open                              1061 non-null   float64
#  4   gspc_high                              1061 non-null   float64
#  5   gspc_low                               1061 non-null   float64
#  6   gspc_close                             1061 non-null   float64
#  7   gspc_volume                            1061 non-null   int64
#  8   gspc_adjusted                          1061 non-null   float64
#  9   xom                                    1061 non-null   float64
#  10  cvx                                    1061 non-null   float64
# dtypes: float64(8), int64(3)
# memory usage: 91.3 KB
# None
#         weekly_date  weekly_ending_stocks_of_gasoline  \
# count   1061.000000                       1061.000000
# mean   40626.707823                     217777.137606
# std     2367.905109                      15941.219499
# min    36528.000000                     178739.000000
# 25%    38572.000000                     205393.000000
# 50%    40623.000000                     215397.000000
# 75%    42667.000000                     228575.000000
# max    44718.000000                     263234.000000
#
#        weekly_regular_retail_gasoline_prices    gspc_open    gspc_high  \
# count                            1061.000000  1061.000000  1061.000000
# mean                                2.538233  1821.523450  1831.671178
# std                                 0.756794   920.515246   924.497627
# min                                 1.059000   680.760000   695.270000
# 25%                                 1.969000  1172.790000  1184.480000
# 50%                                 2.552000  1419.890000  1426.940000
# 75%                                 3.068000  2173.710000  2183.480000
# max                                 4.876000  4778.140000  4796.640000
#
# 9      1456.63    920800000        1456.63  38.09  41.78
# 10     1523.86    901000000        1523.86  38.62  42.09
# 11     1505.97   1021700000        1505.97  38.88  46.31
# 12     1504.46    853700000        1504.46  39.50  42.72
# 13     1401.44   1204700000        1401.44  39.31  42.50
# 14     1429.86    868700000        1429.86  39.31  42.66
# 15     1468.25    966300000        1468.25  39.16  42.75
# 16     1424.17    787600000        1424.17  39.94  45.53
# 17     1452.36    854600000        1452.36  40.97  46.91
# 18     1400.72    869000000        1400.72  41.19  46.91
# 19     1467.63    838600000        1467.63  39.50  45.38

# %%
plt.scatter(new_data.gspc_close, new_data.weekly_regular_retail_gasoline_prices)
plt.xlabel('gspc_close')
plt.ylabel('weekly_regular_retail_gasoline_prices')
plt.show()

# %%
#The data in the df column must be reshaped into an array with shape (num_samples, num_features)
#https://stackoverflow.com/questions/18691084/what-does-1-mean-in-numpy-reshape
X = data_df.gspc_close.values.reshape(-1, 1)

# %%
X[:5]
# Out:
# array([[1455.22],
#        [1457.6 ],
#        [1401.53],
#        [1394.46],
#        [1424.24]])

# %%
# The shape of X with 1060 samples and a single feature (column)
X.shape
# Out:
# (1061, 1)

# %%
y = new_data.weekly_regular_retail_gasoline_prices

# %%
# Create a model with scikit-learn
#Perform linear regression with 9 columns
model = LinearRegression()

# %%
# Fit the data into the model
# By convention, X is capitalized and y is lowercase
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# The model creates predicted y values based on X values
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1061,)

# %%
df = (X, y_pred)

# %%
df[:5]
# Out:
# (array([[1455.22],
#         [1457.6 ],
#         [1401.53],
#         ...,
#         [4008.01],
#         [3973.75],
#         [4121.43]]),
#  array([2.45305079, 2.45360418, 2.44056704, ..., 3.04661408, 3.0386481 ,
#         3.07298599]))

# %%
# Plot the results. The best fit line is red.
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
#The slope indicates the steepness of a line and the intercept indicates the location where it intersects an axis.
#The slope and the intercept define the linear relationship between two variables, and can be used to estimate an average rate of change.
#The greater the magnitude of the slope, the steeper the line and the greater the rate of change which means one variable is dependent of the other. 
#Examining the specific parementers of our model
# The slope
# The y-intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00023252]
# 2.1146895650137174

# %%
#reading into variables
X = data_df.gspc_close.values.reshape(-1, 1)
y = new_data.weekly_regular_retail_gasoline_prices

# %%
#Split the Dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 213, random_state = 100)

# %%
X_train.shape
# Out:
# (848, 1)

# %%
y_train.shape
# Out:
# (848,)

# %%
X_test.shape
# Out:
# (213, 1)

# %%
y_test.shape
# Out:
# (213,)

# %%
#import linear regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
#fitting the model
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = lr.predict(X_test)

# %%
#Visualisation

# %%
#traininig set
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, lr.predict(X_train), color = 'blue')
plt.title('GSPC Close price vs. Weekly Gasoline Prices (Training set)')
plt.xlabel('GSPC Close')
plt.ylabel(' Weekly Gasoline Prices')
plt.show()

# %%
# Visualising the Test set results
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, lr.predict(X_train), color = 'blue')
plt.title('GSPC Close price vs. Weekly Gasoline Prices (Test set)')
plt.xlabel('GSPC Close')
plt.ylabel('Weekly Gasoline Prices')
plt.show()

# %%
#actual vs predicted price on TEST DATA
fig, ax=plt.subplots(figsize=(27,7))
sns.lineplot(x=y_test.index,y=y_test,label='Actuals',color='blue',ax=ax)
sns.lineplot(x=y_test.index,y=y_pred,label='Predictions',color='red',ax=ax)
ax.set_title('Price: Actuals vs Predictions for Test Data')
ax.set_ylabel('Price')
ax.set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
from sklearn.metrics import mean_squared_error
lr_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
lr_rmse
# Out:
# 0.7050899847099118

# %%
#Root Mean Square Error (RMSE) is the standard deviation of the residuals (prediction errors).

# %%
from yellowbrick.regressor import PredictionError
# Instantiate the linear model and visualizer
Lm = Lasso()
visualizer = PredictionError(Lm) 
# fit visualizer on training data
visualizer.fit(X_train, y_train) 
#Evaluate on test data
visualizer.score(X_test, y_test)
#show the plot and save in given path
visualizer.show("prediction_error.jpg")
# Out:
# <AxesSubplot:title={'center':'Prediction Error for Lasso'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
model1 = LinearRegression()
visualizer = PredictionError(model1)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.show("prediction_error_for_Linear_Regression.jpg")
# Out:
# <AxesSubplot:title={'center':'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
visualizer = ResidualsPlot(model1)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.show("residuals_for_Linear_Regression.jpg")
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
from sklearn.metrics import mean_squared_error
lr_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
lr_rmse
# Out:
# 0.7671114762339721

# %%
#Root Mean Square Error (RMSE) is the standard deviation of the residuals (prediction errors).

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=5, include_bias=False)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)
pol_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Truth or Bluff (Linear Regression)')
    plt.xlabel('Stock Price')
    plt.ylabel('Gas Price')
    plt.show()
    return
viz_polymonial()

# %%
# Additional feature
# Making the plot line (Blue one) more smooth
def viz_polymonial_smooth():
    X_grid = np.arange(min(X), max(X), 0.1)
    X_grid = X_grid.reshape(len(X_grid), 1) #Why do we need to reshape? (https://www.tutorialspoint.com/numpy/numpy_reshape.htm)
    # Visualizing the Polymonial Regression results
    plt.scatter(X, y, color='red')
    plt.plot(X_grid, pol_reg.predict(poly_reg.fit_transform(X_grid)), color='blue')
    plt.title('Truth or Bluff (Linear Regression)')
    plt.xlabel('Stock Price')
    plt.ylabel('Gas Price')
    plt.show()
    return
viz_polymonial_smooth()

# %%
pol_reg_y_predicted = pol_reg.predict(X_test)
from sklearn.metrics import mean_squared_error
pol_reg_rmse = np.sqrt(mean_squared_error(y_test, pol_reg_y_predicted))
pol_reg_rmse
# Out:
# 0.6459460141795336

# %%
# Predicting a new result with Linear Regression
lr.predict([[1505.97]])
#The actual number is 1.503
# Out:
# array([2.47487911])

# %%
# Predicting a new result with Polymonial Regression
pol_reg.predict(poly_reg.fit_transform([[1505.97]]))
# Out:
# array([2.81717812])

# %%
#They're both close to the mean for the weekly gas price whhich is 2.538233
